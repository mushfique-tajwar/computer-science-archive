# %% [markdown]
# Python variables are the reserved memory locations used to store values with in a Python Program.

# %% [markdown]
# ### Creating Python Variables

# %%
counter = 100          # Creates an integer variable
miles   = 1000.0       # Creates a floating point variable
name    = "Rutab"   # Creates a string variable

# %%
a, b, c = 10, 20, 30

# %% [markdown]
# ### Printing Python Variables

# %%
print(counter)
print(miles)
print(name)
# Out:
# 100
# 1000.0
# Rutab

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Deleting Python Variables

# %%
counter = 100
print(counter)

del counter
print(counter)
# Out:
# 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 print (counter)
#       4 del counter
# ----> 5 print (counter)
#
# NameError: name 'counter' is not defined

# %% [markdown]
# ### Getting Type of a Variable

# %%
x = "Rutab"
y =  10
z =  10.10

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### Python Variables - Naming Convention
#
# - A variable name must start with a letter or the underscore character
# - A variable name cannot start with a number or any special character like $, (, * % etc.
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# - Python variable names are case-sensitive which means Name and NAME are two different variables in Python.
# - Python reserved keywords cannot be used naming the variable.

# %% [markdown]
# ### Python Types Based on Scope

# %% [markdown]
# **1. Global Variables:** Any variables that are outside a function and can be used anywhere.

# %%
x = 5
y = 10
def sum():
   sum = x + y
   return sum
print(sum())
# Out:
# 15

# %% [markdown]
# **2. Local Variable:** The variables that are inside a function and can't be used outside that function.

# %%
def sum(x,y):
   sum = x + y
   return sum
print(sum(7, 10))
# Out:
# 17

# %% [markdown]
# ### Python Types Based on Ecapsulation

# %% [markdown]
# - **Public Variables:** Public variables are accessible from anywhere, both inside and outside the class. In the image, a public place is considered as an analogy for public variables as they can be accessed by anyone.
# - **Protected Variables:** Protected variable can be accessed within the class and its subclasses. In the image, a private domicile is considered as an analogy for protected variables as they can be accessed by family members (subclasses) but not by outsiders.
# - **Private Variables:** Private variables are only accessible within the class they are defined in. In the image, a vault is considered as an analogy for private variables as they can only be accessed by the owner (the class itself) and not by anyone else.
